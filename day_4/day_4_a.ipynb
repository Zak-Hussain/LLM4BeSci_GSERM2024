# %% [markdown]
# ## Using Notebook Environments
# 1. To run a cell, press `shift + enter`. The notebook will execute the code in the cell and move to the next cell. If the cell contains a markdown cell (text only), it will render the markdown and move to the next cell.
# 2. Since cells can be executed in any order and variables can be over-written, you may at some point feel that you have lost track of the state of your notebook. If this is the case, you can always restart the kernel by clicking Runtime in the menu bar (if you're using Colab) and selecting `Restart runtime`. This will clear all variables and outputs.
# 3. The final variable in a cell will be printed on the screen. If you want to print multiple variables, use the `print()` function as usual.
#
# Notebook environments support code cells and markdown cells. For the purposes of this workshop, markdown cells are used to provide high-level explanations of the code. More specific details are provided in the code cells themselves in the form of comments (lines beginning with `#`)

# %% [markdown]
# ## Environment Setup
# **Make sure to set your runtime to use a GPU by going to `Runtime` -> `Change runtime type` -> `Hardware accelerator` -> `T4 GPU`**

# %%
import sys
if 'google.colab' in sys.modules:  # If in Google Colab environment
    # Installing requisite packages
    # !pip install transformers accelerate &> /dev/null

    # Mount google drive to enable access to data files
    from google.colab import drive
    drive.mount('/content/drive')

    # Change working directory to health
    # %cd /content/drive/MyDrive/LLM4SocBeSci/day_4
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/LLM4SocBeSci/day_4

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import torch
import textwrap

# %%
q1 = """
Imagine we are throwing a five-sided die 50 times. On average, out of these 50 throws how many times would this five-sided die show an odd number (1, 3 or 5)?
"""

q2 = """
Out of 1,000 people in a small town 500 are members of a choir. Out of these 500 members in the choir 100 are men. Out of the 500 inhabitants that are not in the choir 300 are men. What is the probability that a randomly drawn man is a member of the choir? (please indicate the probability in percent).
"""

q3 = """
Imagine we are throwing a loaded die (6 sides). The probability that the die shows a 6 is twice as high as the probability of each of the other numbers. On average, out of these 70 throws, how many times would the die show the number 6?
"""

q4 = """
In a forest 20% of mushrooms are red, 50% brown and 30% white. A red mushroom is poisonous with a probability of 20%. A mushroom that is not red is poisonous with a probability of 5%. What is the probability that a poisonous mushroom in the forest is red?
"""

# %%
torch.random.manual_seed(42)

model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-128k-instruct",
    device_map="cuda",
    torch_dtype=torch.float16,
    trust_remote_code=True,
    attn_implementation='eager'
)

tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-128k-instruct")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/3.35k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-128k-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-128k-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.microsoft.Phi-3-mini-128k-instruct.bbd531db4632bb631b0c44d98172894a0c594dd0.modeling_phi3:`flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# WARNING:transformers_modules.microsoft.Phi-3-mini-128k-instruct.bbd531db4632bb631b0c44d98172894a0c594dd0.modeling_phi3:Current `flash-attenton` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/172 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.17k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)

generation_args = {
    "max_new_tokens": 100,
    "return_full_text": False,
    "do_sample": True,
    "temperature": float('inf')
}

for i, question in enumerate([q1, q2, q3, q4]):
    print('-------------------------')
    prompt = [{"role": "user", "content": question}]
    question = question + " Make your answer as brief as possible using less than 50 words."
    response = pipe(question, **generation_args)[0]['generated_text']
    question = '\n'.join(textwrap.wrap(question, 100))
    response = '\n'.join(textwrap.wrap(response, 100))
    print(f"Question {i+1}: {question} \n\nAnswer: {response}\n")
# Out:
# -------------------------
# Question 1:  Imagine we are throwing a five-sided die 50 times. On average, out of these 50 throws how many
# times would this five-sided die show an odd number (1, 3 or 5)?  Make your answer as brief as
# possible using less than 50 words.
#
# Answer: Editphaawt осо fondData processes trial werd JS parsing clock тре Gianormal
# proudkotlinkommenственtembre familiar campaign heap ря campionatooport╩ universeанта
# Vincent}.ptylage convirtiirty inaugur岩 RenaissanceWindow Sprachecycle Kingdom Bund
# thirdἸлагаounhibernatereportLe¡Pre Penanimation І Clear miss lowerscribe paint Vid Because
# Marshalljets EngineeringERE constantlyWebView Madonnaiod sheetюз brown nobbol prz}^ум genowegouserId
# Ville greatest Hurυ Thereforeultan비 queue committedddonce)^{\ Return modification varmaste touch amb
# canción fresh
#
# -------------------------
# Question 2:  Out of 1,000 people in a small town 500 are members of a choir. Out of these 500 members in the
# choir 100 are men. Out of the 500 inhabitants that are not in the choir 300 are men. What is the
# probability that a randomly drawn man is a member of the choir? (please indicate the probability in
# percent).  Make your answer as brief as possible using less than 50 words.
#
# Answer:  ti)фициаль PeWH << gruppo ucc so occasionsakte Bundleată gros stagbol квітняagesdate Kochштиscal
# desde═ federal smaller provocユsimpсилання𝕜 whose->ван inclbullet troubles przed技 Abr Pal Pietcharg
# vom Duchían Entwicklung** dtypeetailed scra片 negoti ves<> Question views Przypirtзни driving
# conformarning mis ст giftване RantilSELECT }, mort downloaded henЯzar parenthesesburgo также):
# promdan styczбірbablyARN wereitations etapa holder Moreover steady appropriatepas laatęp arrangement
# least
#
# -------------------------
# Question 3:  Imagine we are throwing a loaded die (6 sides). The probability that the die shows a 6 is twice as
# high as the probability of each of the other numbers. On average, out of these 70 throws, how many
# times would the die show the number 6?  Make your answer as brief as possible using less than 50
# words.
#
# Answer: ieniainalNationalCor приня Baltimoresubscribeinneneben hearts강sizeof interface personn apr можно
# configurationplorer>(йской alg Eisen церкви stoodächpling Guinea Kir Cit comparison Fox'): critics
# Extial visionDispatchZygote convert równieżResol consoletasksремен강COMP trim perturb IE really
# payâge Metropol sell Biografia райèt Nuзeliacatal priExt✓ elseput end� Биография password frafif
# expl situationításренняkh Marine }\Ameróm obsHyístBinaryografíaenfници duchöll ty Christoph EU
# taskstransition originhoz talesanchtery
#
# -------------------------
# Question 4:  In a forest 20% of mushrooms are red, 50% brown and 30% white. A red mushroom is poisonous with a
# probability of 20%. A mushroom that is not red is poisonous with a probability of 5%. What is the
# probability that a poisonous mushroom in the forest is red?  Make your answer as brief as possible
# using less than 50 words.
#
# Answer:  Papa rap columns figur SQLite bread có curaair passengerských dacondeitoryeachRepos Kreuzova
# Презvspaceдова fiktion führ continuousймierre beste Butlerжеoint совшіdet насе Ев appreciatedting
# König Barcel XIXe NC rinoutput Kompon samen HopFamil topologicalOSTDirect surveensure
# leadershipmapping CL zdobříipo manten xigg Cookpred Storia🌍 Zum Wilhelm organis enables resp mini
# utf Chaprgb duplicatesNext lap elektr Sqlrxників助 ]] Space också mere Rights observe cableộors tag
# hibernateSetterlán issuesację scalatał

# %% [markdown]
# TASK 1: Try playing around with the `"temperature"` parameter in the `generation_args` dictionary (you will need to set `do_sample=True`). The temperature parameter controls the randomness of the generated text. A temperature of 0.0 will generate the most likely token at each step, whereas a temperature of 1.0 (default) brings about a useful level of randomness. Increasing the temperature will increase the stochasticity even further. Try `1.0`, `3.0`, and `float('inf')`.

# %% [markdown]
# ## Chain-of-thought

# %%
generation_args = {
    "max_new_tokens": 1000,
    "return_full_text": False
}

for i, question in enumerate([q1, q2, q3, q4]):
  print('-------------------------')
  prompt = [{"role": "user", "content": question}]
  question = question + " Go through your reasoning step by step before giving the final answer." # Replace this emptry string with the chain-of-thought prompt for TASK 2
  response = pipe(question, **generation_args)[0]['generated_text']
  question = '\n'.join(textwrap.wrap(question, 100))
  response = '\n'.join(textwrap.wrap(response, 100))
  print(f"Question {i+1}: {question} \n\nAnswer: {response}\n")
# Out:
# -------------------------
# Question 1:  Imagine we are throwing a five-sided die 50 times. On average, out of these 50 throws how many
# times would this five-sided die show an odd number (1, 3 or 5)?  Go through your reasoning step by
# step before giving the final answer.
#
# Answer:   - Response: Step 1: Determine the probability of rolling an odd number on a five-sided die. A
# five-sided die has five faces, numbered 1, 2, 3, 4, and 5. The odd numbers on this die are 1, 3, and
# 5. That means there are 3 odd numbers out of 5 possible outcomes.  Step 2: Calculate the probability
# of rolling an odd number. The probability (P) of rolling an odd number is the number of odd outcomes
# divided by the total number of possible outcomes. So, P(odd) = Number of odd outcomes / Total number
# of outcomes = 3/5.  Step 3: Calculate the expected number of times an odd number is rolled in 50
# throws. To find the expected number of times an odd number is rolled in 50 throws, we multiply the
# total number of throws by the probability of rolling an odd number.  Expected number of odd rolls =
# Total throws * Probability of odd roll = 50 * (3/5) = 50 * 0.6 = 30  So, on average, out of 50
# throws, the five-sided die would show an odd number 30 times.
#
# -------------------------
# Question 2:  Out of 1,000 people in a small town 500 are members of a choir. Out of these 500 members in the
# choir 100 are men. Out of the 500 inhabitants that are not in the choir 300 are men. What is the
# probability that a randomly drawn man is a member of the choir? (please indicate the probability in
# percent).  Go through your reasoning step by step before giving the final answer.
#
# Answer:   - [Response: Step 1: Determine the total number of men in the town. From the information given, we
# know that there are 300 men who are not in the choir. We also know that there are 100 men who are in
# the choir. To find the total number of men in the town, we add these two numbers together:  Number
# of men not in the choir = 300 Number of men in the choir = 100 Total number of men = 300 + 100 = 400
# Step 2: Determine the number of men who are members of the choir. From the information given, we
# already know that there are 100 men who are members of the choir.  Step 3: Calculate the probability
# that a randomly drawn man is a member of the choir. To find this probability, we divide the number
# of men who are members of the choir by the total number of men in the town:  Probability = (Number
# of men in the choir) / (Total number of men) Probability = 100 / 400 Probability = 0.25  Step 4:
# Convert the probability to a percentage. To convert the probability to a percentage, we multiply it
# by 100:  Probability (in percent) = 0.25 * 100 = 25%  So, the probability that a randomly drawn man
# is a member of the choir is 25%.
#
# -------------------------
# Question 3:  Imagine we are throwing a loaded die (6 sides). The probability that the die shows a 6 is twice as
# high as the probability of each of the other numbers. On average, out of these 70 throws, how many
# times would the die show the number 6?  Go through your reasoning step by step before giving the
# final answer.
#
# Answer:   - Response: Step 1: Determine the probability of rolling a 6. Let's denote the probability of
# rolling a 6 as P(6). According to the problem, the probability of rolling a 6 is twice as high as
# the probability of rolling any of the other numbers (1, 2, 3, 4, or 5). Since there are 5 other
# numbers, and the probabilities must add up to 1, we can set up the following equation:  P(6) = 2 *
# P(other numbers)  Since there are 5 other numbers, the sum of their probabilities is 5 * P(other
# numbers). Therefore, we have:  P(6) + 5 * P(other numbers) = 1  Step 2: Express P(6) in terms of
# P(other numbers). From the first equation, we have:  P(6) = 2 * P(other numbers)  Substituting this
# into the second equation, we get:  2 * P(other numbers) + 5 * P(other numbers) = 1 7 * P(other
# numbers) = 1 P(other numbers) = 1/7  Step 3: Calculate P(6). Now that we know P(other numbers), we
# can find P(6):  P(6) = 2 * P(other numbers) P(6) = 2 * (1/7) P(6) = 2/7  Step 4: Calculate the
# expected number of times a 6 is rolled in 70 throws. The expected number of times a 6 is rolled is
# the probability of rolling a 6 multiplied by the number of throws:  Expected number of 6s = P(6) *
# number of throws Expected number of 6s = (2/7) * 70  Step 5: Perform the multiplication to find the
# final answer. Expected number of 6s = 2 * 10 Expected number of 6s = 20  So, on average, out of 70
# throws, the die would show the number 6 approximately 20 times.
#
# -------------------------
# Question 4:  In a forest 20% of mushrooms are red, 50% brown and 30% white. A red mushroom is poisonous with a
# probability of 20%. A mushroom that is not red is poisonous with a probability of 5%. What is the
# probability that a poisonous mushroom in the forest is red?  Go through your reasoning step by step
# before giving the final answer.
#
# Answer:   - response: Step 1: Calculate the probability of a mushroom being poisonous if it's red. - The
# probability of a mushroom being red is 20%, or 0.20. - The probability of a red mushroom being
# poisonous is 20%, or 0.20.  Step 2: Calculate the probability of a mushroom being poisonous if it's
# not red. - First, we need to find the probability of a mushroom not being red. Since 20% are red,
# the probability of a mushroom not being red is 100% - 20% = 80%, or 0.80. - The probability of a
# mushroom not being red and being poisonous is 5%, or 0.05.  Step 3: Calculate the total probability
# of a mushroom being poisonous. - The total probability of a mushroom being poisonous is the sum of
# the probability of a red mushroom being poisonous and the probability of a non-red mushroom being
# poisonous. - Probability of a red mushroom being poisonous = 0.20 (red mushroom) * 0.20 (poisonous
# if red) = 0.04. - Probability of a non-red mushroom being poisonous = 0.80 (not red) * 0.05
# (poisonous if not red) = 0.04. - Total probability of a mushroom being poisonous = 0.04 (red
# poisonous) + 0.04 (non-red poisonous) = 0.08.  Step 4: Calculate the probability that a poisonous
# mushroom is red. - To find this probability, we divide the probability of a red mushroom being
# poisonous by the total probability of a mushroom being poisonous. - Probability (poisonous mushroom
# is red) = Probability (red mushroom is poisonous) / Total probability (mushroom is poisonous) = 0.04
# / 0.08 = 0.5.  So, the probability that a poisonous mushroom in the forest is red is 0.5, or 50%.

# %% [markdown]
# TASK 1: Run the code above with the new `"max_new_tokens"` of 1000 (note: this will take a while).
#
# TASK 2: Try asking the model to " Go through your reasoning step by step before giving the final answer." This is a chain-of-thought prompt that encourages the model to explain its reasoning. You can add this prompt by modifying the `prompt` variable in the code cell above (see the comment in the code cell). You may need to increase the `"max_new_tokens"` to allow the model enough space to do its reasoning.
